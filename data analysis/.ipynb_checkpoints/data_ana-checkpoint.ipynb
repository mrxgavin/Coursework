# %%
# -*- coding: utf-8 -*-
import pandas as pd
#from pyecharts import ,

from pyecharts.charts import Pie
from pyecharts.charts import Line
from pyecharts.charts import Scatter
import os 
import numpy as np
import jieba
import jieba.analyse
from wordcloud import WordCloud,ImageColorGenerator
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
 
font = FontProperties(fname=r'c:\windows\fonts\simsun.ttc')#,size=20指定本机的汉字字体位置

os.chdir('G:\\work-cell')

datas = pd.read_csv('gzxb.csv',index_col = 0,encoding = 'UTF-8')

# %%
datas.head()
# Out:
#            score  disliked  likes  liked       ctime  score.1  \
# author
# 緖山まひろ         10         0  10032      0  1530982477       10
# 平民通宵刷魔界       10         0      0      0  1560616086       10
# 无可灬奉告          8         0      0      0  1560614168        8
# 苏联战列小喀琅       10         0      0      0  1560584262       10
# 老蕾同志的蕾丝胖次      8         0      0      0  1560583957        8
#
#                                                      content last_ep_index  \
# author
# 緖山まひろ                            我有个想法，动物体内的细胞会不会是兽耳呢d(ŐдŐ๑)             0
# 平民通宵刷魔界                                            超喜欢这番，爱死啦             0
# 无可灬奉告      说实话，我就是冲着血小板来的，但除了第一集其他几集都没特别出色的表现。不过整个看下来观感还是...             0
# 苏联战列小喀琅                                     话不多说，这么久才来评分，有愧啊             0
# 老蕾同志的蕾丝胖次                                          后半有点划水趋势⑧             0
#
#                    cursor                 date
# author
# 緖山まひろ      77567116085922  2018-07-07 16:54:37
# 平民通宵刷魔界    77567116085922  2019-06-15 16:28:06
# 无可灬奉告      77567116085922  2019-06-15 15:56:08
# 苏联战列小喀琅    77567116085922  2019-06-15 07:37:42
# 老蕾同志的蕾丝胖次  77567116085922  2019-06-15 07:32:37

# %% [markdown]
# ## 描述性分析

# %%
#del datas['ctime']
#del datas['cursor']
#del datas['liked']
# 评分

scores = datas.score.groupby(datas['score']).count()
pie1 = Pie("评分"0)
pie1.add(
    "评分",
    ['一星','二星','三星','四星','五星'],
    scores.values,
    radius=[40, 75],
#    center=[50, 50],
    is_random=True,
#    radius=[30, 75],
    is_legend_show=False,
    is_label_show=True,
)
pie1.render('评分.html')



datas['dates'] = datas.date.apply(lambda x:pd.Timestamp(x).date())
datas['time'] = datas.date.apply(lambda x:pd.Timestamp(x).time().hour)


num_date = datas.author.groupby(datas['dates']).count()

# 评论数时间分布
chart = Line("评论数时间分布")
chart.use_theme('dark')
chart.add( '评论数时间分布',num_date.index, num_date.values, is_fill=True, line_opacity=0.2,
          area_opacity=0.4, symbol=None)

chart.render('评论时间分布.html')

# 好评字数分布
datalikes = datas.loc[datas.likes>5]
datalikes['num'] = datalikes.content.apply(lambda x:len(x))
chart = Scatter("likes")
chart.use_theme('dark')
chart.add('likes', np.log(datalikes.likes), datalikes.num, is_visualmap=True,
               xaxis_name = 'log(评论字数)',
               
          )
chart.render('好评字数分布.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-a74269bdde94> in <module>()
#       5
#       6 scores = datas.score.groupby(datas['score']).count()
# ----> 7 pie1 = Pie("评分")
#       8 pie1.add(
#       9     "评分",
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyecharts\charts\basic_charts\pie.py in __init__(self, init_opts)
#      15
#      16     def __init__(self, init_opts: opts.InitOpts = opts.InitOpts()):
# ---> 17         super().__init__(init_opts=init_opts)
#      18
#      19     def add(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyecharts\charts\chart.py in __init__(self, init_opts)
#      12 class Chart(Base):
#      13     def __init__(self, init_opts: opts.InitOpts = opts.InitOpts()):
# ---> 14         super().__init__(init_opts=init_opts)
#      15         self.colors = (
#      16             "#c23531 #2f4554 #61a0a8 #d48265 #749f83 #ca8622 #bda29a #6e7074 "
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyecharts\charts\base.py in __init__(self, init_opts)
#      23
#      24     def __init__(self, init_opts: InitOpts = InitOpts()):
# ---> 25         self.width = init_opts.width
#      26         self.height = init_opts.height
#      27         self.renderer = init_opts.renderer
#
# AttributeError: 'str' object has no attribute 'width'
